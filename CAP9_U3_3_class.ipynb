# %% [markdown]
# ![Imagen inicial slides.png](data:image/png;base64,...)

# %% [markdown]
# # <font size="6" color="gray">Capítulo 9</font><br>
#
# <font size="50" color="lighblue">Varios temas de aprendizaje profundo: <br> Arquitecturas para imágenes, datos secuenciales y redes generativas.
# </font><br>
#
#
# <font size="6" color="lighblue">Curso AI</font>

# %% [markdown]
# ###Descripción del capítulo
#
# #### *Objetivos del capítulo:*
#
# * Construye y entrena redes neuronales convolucionales para la clasificación de imágenes.
# * Redes neuronales convolucionales (CNN en inglés) para detectar patrones correlacionados localmente en imágenes.
# * Construye y entrena redes neuronales recurrentes para el pronóstico de series temporales y el procesamiento del lenguaje natural.
# * Breve descripción general del LSTM.
# * AutoEncoders para reducción dimensional y extracción de características.
# * Breve introducción a las redes generativas adversarias (GAN en inglés).
#
# #### *Contenidos del capítulo:*
#
# * Unidad 1. Modelo CNN
# * **Unidad 2. RNN para modelado de datos secuenciales**
# * Unidad 3. Red neuronal adversaria generativa (GAN) para crear imágenes inexistentes

# %% [markdown]
# ## <font size="6" color="gray">Unidad 3.</font><br>
#
# <font size="50" color="lighblue">Red neuronal adversaria generativa para crear imágenes inexistentes</font> <br>
#
# 3.1. Codificador automático<br>
# 3.2. Acerca de las redes generativas adversarias (GAN)<br>
# **3.3. Ejercicio de redes generativas adversarias**<br>

# %% [markdown]
# ### Red neuronal convolucional (CNN)
#
# #### Entrenamiento del modelo `GAN` en Google Colab
#
# * El ejercicio de código de este capítulo requiere `mayores recursos` que una computadora portátil sin la `GPU` o la potencia informática de una estación de trabajo.
# </br>
#
# * Si tienes una computadora con `GPU NVIDIA` y has instalado la librería `cuDNN`, puedes aumentar la velocidad de cálculo.
# </br>
#
# * Aquí utilizaremos `Google Colab`, un servicio gratuito de computación en la nube, porque estos recursos informáticos de alto rendimiento generalmente no están disponibles.
# </br>
#
# * Google Colab ofrece instancias de `Jupyter Notebook` en la nube.
# </br>
#
# * Este Notebook se puede guardar en `Google Drive` o `GitHub`.
# </br>
#
# * Colab ofrece muchos recursos informáticos como `CPU`, `GPU` e incluso `TPU`, pero limita su tiempo de funcionamiento a 12 horas.
# </br>
#
# * La máquina asignada se apaga después de `12 horas` de funcionamiento.
# </br>
#
# * El ejercicio de código en este capítulo solo requiere un máximo de `2 a 3 horas`.
# </br>
#
# * Para proyectos que se ejecutan durante más de 12 horas, se recomienda guardar los resultados intermedios como archivos de `puntos de control`.

# %% [markdown]
# #### Entrenamiento del modelo GAN en Google Colab
#
# ![SIC2023_C9_U3_P106.png](data:image/png;base64,...)
#
# ```
# Google Colab es fácil de usar.
# Si visitas https://colab.research.google.com, te preguntarás dónde guardar Jupyter Notebook.
# Haz clic en la pestaña Google Drive en esta ventana.
# Al hacer esto, puedes guardar el Notebook en Google Drive.
# Luego, haz clic en el enlace del nuevo Notebook al final para crear un nuevo Notebook.
# ```

# %% [markdown]
# #### Construyendo un modelo GAN desde cero
#
# * Como siguiente paso, veamos cómo ejecutar el código de la computadora portátil usando `GPU`:
#
# ![SIC2023_C9_U3_P107.png](data:image/png;base64,...)

# %% [markdown]
# * Elige el `entorno de ejecución` en la barra de menú, haciendo clic en Cambio de tipo de tiempo de ejecución y selecciona `GPU` como en la figura:
#
# ![SIC2023_C9_U3_P108.png](data:image/png;base64,...)

# %% [markdown]
# #### Entrenamiento del modelo GAN en Google Colab
#
# * Verifiquemos la compatibilidad de GPU para la versión instalada de TensorFlow usando el siguiente código:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
print("GPU compatibility:", len(tf.config.list_physical_devices("GPU")) > 0)

if tf.config.list_physical_devices("GPU"):
  device_name = tf.test.gpu_device_name( )
else:
  device_name = 'cpu: 0'

print(device_name)
# Out:
# GPU compatibility: True
# /device:GPU:0

# %% [markdown]
# #### Construcción de redes neuronales generadoras y discriminadoras.
#
# * Construyamos el generador y discriminador del primer modelo GAN como una red neuronal completamente conectada con una o más capas ocultas (consulta la siguiente figura).
# </br>
#
# * Este modelo es la versión GAN original y se llama vanilla GAN.
#
#  ![SIC2023_C9_U3_P110.png](data:image/png;base64,...)
#
# * Este modelo utiliza la función de activación `LeakyReLu` para cada capa oculta.
#
# * ReLu produce un `gradiente disperso`. Sin embargo, esto no es adecuado para casos en los que se necesitan gradientes en todos los rangos de valores de entrada.
#
# * En la red neuronal discriminadora, la capa de `abandono` sigue a la capa oculta.
#
# * La capa de salida del generador utiliza la función de activación de tangente hiperbólica (tanh). El uso de la función de activación `tanh `en la red neuronal del generador ayuda al proceso de aprendizaje.
#
# * La capa de salida del discriminador no tiene una función de activación para calcular el logit (es decir, utiliza la función de activación lineal).
#
# * O podría usar la función de activación `sigmoidea` para devolver la probabilidad como salida.

# %% [markdown]
# #### Definamos las dos funciones auxiliares para las dos redes neuronales.
#
# * Esta función construye un modelo con la clase Keras Sequential, y el código con la capa mencionada es el siguiente:

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt

# %%
## Definir la función del generador:

def make_generator_network(
    num_hidden_layers = 1,
    num_hidden_units = 100,
    num_output_units = 784):
  model = tf.keras.Sequential()
  for i in range (num_hidden_layers):
    model.add(
        tf.keras.layers.Dense(
            units = num_hidden_units,
            use_bias = False)
        )
    model.add(tf.keras.layers.LeakyReLU())

  model.add(tf.keras.layers.Dense(
      units=num_output_units, activation='tanh'))
  return model

# %%
## Definir la función discriminadora:
def make_discriminator_network(
    num_hidden_layers = 1,
    num_hidden_units = 100,
    num_output_units = 1):
  model = tf.keras.Sequential()
  for i in range (num_hidden_layers) :
    model.add(tf.keras.layers.Dense(units=num_hidden_units))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Dropout(rate = 0.5))

  model.add(
      tf.keras.layers.Dense(
          units = num_output_units,
          activation = None)
      )
  return model

# %% [markdown]
# * Configuramos para entrenar el siguiente modelo.
#
# * El tamaño de la imagen MNIST es de 28 x 28 píxeles. El archivo MNIST tiene un solo canal de color ya que es una imagen en `blanco y negro`.
#
# * Luego, establezca el tamaño del vector de entrada $z$ en $20$ e inicialice aleatoriamente el valor de peso a partir de una distribución uniforme.
#
# * Usaremos capas completamente conectadas y una única capa oculta con $100$ unidades en cada red neuronal para construir una GAN `muy simple` que sirva como ejemplo.
#
# * Generamos e inicializamos dos redes neuronales en el siguiente código.
# * Cargue el método summary() de Keras.

# %%
image_size = (28, 28)
z_size = 20        # Vector latente
mode_z = 'uniform' # 'uniform' vs. 'normal'
gen_hidden_layers = 1
gen_hidden_size = 100
disc_hidden_layers = 1
disc_hidden_size = 100

tf.random.set_seed(1)

gen_model = make_generator_network(
    num_hidden_layers = gen_hidden_layers,
    num_hidden_units = gen_hidden_size,
    num_output_units = np.prod(image_size))

gen_model.build(input_shape=(None, z_size))
gen_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               2000
#
#  leaky_re_lu (LeakyReLU)     (None, 100)               0
#
#  dense_1 (Dense)             (None, 784)               79184
#
# =================================================================
# Total params: 81184 (317.12 KB)
# Trainable params: 81184 (317.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
disc_model = make_discriminator_network(
    num_hidden_layers = disc_hidden_layers,
    num_hidden_units  = disc_hidden_size)

disc_model.build(input_shape=(None, np.prod(image_size)))
disc_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 100)               78500
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 100)               0
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 78601 (307.04 KB)
# Trainable params: 78601 (307.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Definir conjunto de datos de prueba
#
# * Como siguiente paso, carguemos el conjunto de datos MNIST y apliquemos los pasos de preprocesamiento necesarios.
# * El rango de valores de píxeles de la imagen sintética es (-1, 1) ya que la capa de salida del generador utiliza la función de activación tanh.
# * El rango de píxeles de la imagen MNIST de entrada es [0,255] (tipo de datos tf.unit8 de TensorFlow).
# * En la etapa de preprocesamiento, cambie el tipo del tensor de imagen de entrada de tf.uint8 a tf.float32 usando la función tf.image.convert_image_dtype.

# %%
mnist_bldr = tfds.builder('mnist')
mnist_bldr.download_and_prepare()
mnist = mnist_bldr.as_dataset(shuffle_files=False)

def preprocess (ex, mode='uniform'):
  image = ex['image']
  image = tf.image.convert_image_dtype(image, tf.float32)
  image = tf.reshape(image, [-1])
  image = image*2 - 1.0
  if mode == 'uniform':
    input_z = tf.random.uniform (
        shape=(z_size,), minval=-1.0, maxval =1.0)
  elif mode == 'normal':
    input_z = tf.random.normal(shape=(z_size,))
  return input_z, image

# %% [markdown]
# * Al cargar esta función también se cambia el rango de intensidad de píxeles a [0, 1].
# * Multiplica 2 y resta 1 para ajustar el rango de intensidad de píxeles a [-1, 1].
# * También cree un vector aleatorio z basado en una distribución aleatoria (distribución estándar o normal ampliamente utilizada en este código).
# * Aquí, devolvemos colectivamente el vector de entrada z y la imagen extraída del conjunto de datos de entrenamiento por conveniencia.

# %% [markdown]
# #### Examinemos el objeto del conjunto de datos:

# %%
mnist_trainset = mnist['train']

print('before preprocessing: ')
example = next(iter(mnist_trainset))['image']
print('dtype: ', example.dtype, ('minimum: {}, maximum: {}'.format(np.min(example), np.max(example))))

mnist_trainset = mnist_trainset.map(preprocess)

print('after preprocessing: ')
example = next(iter(mnist_trainset))[0]
print ('dtype: ', example.dtype, ('minimum: {}, maximum: {}'.format(np.min(example), np.max(example))))
# Out:
# before preprocessing:
# dtype:  <dtype: 'uint8'> minimum: 0, maximum: 255
# after preprocessing:
# dtype:  <dtype: 'float32'> minimum: -0.8737728595733643, maximum: 0.9460210800170898

# %% [markdown]
# #### En el siguiente código, imprimamos el vector de entrada y la forma de la matriz de imágenes extrayendo un lote:

# %%
mnist_trainset = mnist_trainset.batch(32, drop_remainder=True)
input_z, input_real = next(iter(mnist_trainset))
print('input-z -- shape:', input_z.shape)
print('input-real -- shape:', input_real.shape)
# Out:
# input-z -- shape: (32, 20)
# input-real -- shape: (32, 784)

# %% [markdown]
# #### Además, ejecutemos el cálculo de propagación frontal del generador y discriminador para comprender el flujo de datos general.
#
# * Primero, que devuelva la salida g_output insertando el lote de vector de entrada z en el generador.
# * Este es el lote de la muestra falsa.
# * Después, que obtenga d_logits_fake, un logit por lotes de la muestra falsa, insertando el lote anterior en el modelo discriminador.
# * Luego, obtenga d_logits_real, un logit para la imagen real, insertando la imagen preprocesada del objeto del conjunto de datos en el modelo discriminador.
#
#  * Se utilizan dos logits, d_logits_fake y d_logits_real, para calcular la función de pérdida durante el entrenamiento.

# %%
# plt.hist(g_output);

# %%
g_output = gen_model(input_z)
print('Generator output -- shape:', g_output.shape)

d_logits_real = disc_model(input_real)
d_logits_fake = disc_model(g_output)
print('discriminator (real) -- shape:', d_logits_real.shape)
print('discriminator (fake) -- shape:', d_logits_fake.shape)
# Out:
# Generator output -- shape: (32, 784)
# discriminator (real) -- shape: (32, 1)
# discriminator (fake) -- shape: (32, 1)

# %%
d_logits_fake
# Out:
# <tf.Tensor: shape=(32, 1), dtype=float32, numpy=
# array([[ 0.02042592],
#        [ 0.16780244],
#        [-0.2807817 ],
#        [-0.00164742],
#        [-0.07674884],
#        [ 0.05121195],
#        [-0.25940394],
#        [ 0.14109465],
#        [ 0.27192172],
#        [ 0.08559436],
#        [-0.08598037],
#        [ 0.03135999],
#        [ 0.14750737],
#        [ 0.1539409 ],
#        [ 0.00199567],
#        [-0.08689927],
#        [ 0.19951941],
#        [-0.1704012 ],
#        [ 0.10015383],
#        [ 0.23876628],
#        [-0.37061006],
#        [ 0.05860177],
#        [-0.36597392],
#        [-0.22168267],
#        [-0.3620113 ],
#        [ 0.04044321],
#        [ 0.25503132],
#        [ 0.09302178],
#        [-0.13884246],
#        [ 0.22663093],
#        [-0.10847589],
#        [-0.06219082]], dtype=float32)>

# %% [markdown]
# #### Entrenamiento del modelo GAN
#
# * A continuación, cree un objeto de clase BinaryCrossentropy para que la función de pérdida calcule la pérdida del generador y del discriminador del lote procesado anteriormente.
# * Para esta operación es necesaria una etiqueta de respuesta para cada salida.
# * Creemos un vector lleno de 1 para el generador.
# * El tamaño de este vector es idéntico al del vector d_logits_fake, que contiene el valor logit de la imagen generada.

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)

## Generador de pérdida
g_labels_real = tf.ones_like(d_logits_fake)
g_loss = loss_fn(y_true=g_labels_real, y_pred=d_logits_fake)
print('Generator loss: {:.4f}'.format(g_loss))
# Out:
# Generator loss: 0.7022

# %% [markdown]
# * El discriminador necesita dos pérdidas.
# * Calculemos la pérdida que detecta una muestra falsa usando d_logits_fake y calculemos la pérdida que detecta una muestra real usando d_logits_real.

# %%
## Discriminador de pérdida
d_labels_real = tf.ones_like(d_logits_real)
d_labels_fake = tf.zeros_like(d_logits_fake)

d_loss_real = loss_fn(y_true=d_labels_real, y_pred=d_logits_real)
d_loss_fake = loss_fn(y_true=d_labels_fake, y_pred=d_logits_fake)

print('Discriminator loss: real {:.41}, fake {:.4f}'.format(d_loss_real.numpy(), d_loss_fake.numpy()))
# Out:
# Discriminator loss: real 0.79878532886505126953125, fake 0.6926

# %%
# %%time
## Con 100 épocas y una una GPU A100 tarda alrededor de 7 minutos
## Con 500 épocas y una una GPU A100 tarda alrededor de 36min 13s
import time
import tensorflow as tf
import numpy as np
import tensorflow_datasets as tfds

## Entrenamiento final (1/6)

import time

num_epochs = 500 ## 100
batch_size = 64
image_size = (28, 28)
z_size = 20
mode_z = 'uniform'
gen_hidden_layers = 1
gen_hidden_size = 100
disc_hidden_layers = 1
disc_hidden_size = 100

tf.random.set_seed(1)
np.random.seed(1)

if mode_z == 'uniform':
  fixed_z = tf.random.uniform(
      shape=(batch_size, z_size), minval=-1, maxval=1)
elif mode_z == 'normal':
  fixed_z = tf.random.normal(
      shape=(batch_size, z_size))

def create_samples(g_model, input_z):
  g_output = g_model (input_z, training=False)
  images = tf.reshape(g_output, (batch_size, *image_size))
  return (images+1)/2.0

## Preparar conjunto de datos
mnist_trainset = mnist['train']
mnist_trainset = mnist_trainset.map(
    lambda ex: preprocess (ex, mode=mode_z))

## Entrenamiento final (2/6)

mnist_trainset = mnist_trainset.shuffle(10000)
mnist_trainset = mnist_trainset.batch(
    batch_size, drop_remainder=True)

## Entrenamiento final (3/6)

# Función para encapsular el bucle de entrenamiento.
@tf.function
def train_step(input_z, input_real, gen_model, disc_model, g_optimizer, d_optimizer, loss_fn):
    # Calcula la pérdida del generador
    with tf.GradientTape() as g_tape:
        g_output = gen_model(input_z)
        d_logits_fake = disc_model(g_output, training=True)
        labels_real = tf.ones_like(d_logits_fake)
        g_loss = loss_fn(y_true=labels_real, y_pred=d_logits_fake)

        # Calcula el gradiente de g_loss.
        g_grads = g_tape.gradient(g_loss, gen_model.trainable_variables)

        # Optimizador: Aplicar gradientes.
        g_optimizer.apply_gradients(
            grads_and_vars=zip(g_grads, gen_model.trainable_variables))

    # Calculemos la pérdida del discriminador.
    with tf.GradientTape() as d_tape:
        d_logits_real = disc_model(input_real, training=True)

        d_labels_real = tf.ones_like(d_logits_real)

        d_loss_real = loss_fn(
            y_true=d_labels_real, y_pred=d_logits_real)

        d_logits_fake = disc_model(g_output, training=True)
        d_labels_fake = tf.zeros_like(d_logits_fake)

        d_loss_fake = loss_fn(
            y_true=d_labels_fake, y_pred=d_logits_fake)

        d_loss = d_loss_real + d_loss_fake

    # Calculamos el gradiente de d_loss.
    d_grads = d_tape.gradient(d_loss, disc_model.trainable_variables)

    # Optimizador: Aplicar gradientes
    d_optimizer.apply_gradients(
        grads_and_vars=zip(d_grads, disc_model.trainable_variables))

    return g_loss, d_loss, d_loss_real, d_loss_fake, d_logits_real, d_logits_fake

## Preparar el modelo
with tf.device(device_name):
  gen_model = make_generator_network(
      num_hidden_layers = gen_hidden_layers,
      num_hidden_units = gen_hidden_size,
      num_output_units = np.prod(image_size))
  gen_model.build(input_shape = (None, z_size))

  disc_model = make_discriminator_network(
      num_hidden_layers = disc_hidden_layers,
      num_hidden_units = disc_hidden_size)
  disc_model.build(input_shape=(None, np.prod(image_size)))

## Función de pérdida y optimizador.
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)
g_optimizer = tf.keras.optimizers.Adam()
d_optimizer = tf.keras.optimizers.Adam()

## Entrenamiento final (4/6)
#### Ejecuta la operación en la instrucción de bucle for en el código final para construir un modelo GAN e iterar el entrenamiento.

all_losses = []
all_d_vals = []
epoch_samples = []

start_time = time.time()
for epoch in range(1, num_epochs+1):
    epoch_losses, epoch_d_vals = [], []
    for i, (input_z, input_real) in enumerate(mnist_trainset):
        g_loss, d_loss, d_loss_real, d_loss_fake, d_logits_real, d_logits_fake = train_step(
            input_z, input_real, gen_model, disc_model, g_optimizer, d_optimizer, loss_fn)

        epoch_losses.append((g_loss.numpy(), d_loss.numpy(),
                            d_loss_real.numpy(), d_loss_fake.numpy()))

        d_probs_real = tf.reduce_mean(tf.sigmoid(d_logits_real))
        d_probs_fake = tf.reduce_mean(tf.sigmoid(d_logits_fake))
        epoch_d_vals.append((d_probs_real.numpy(), d_probs_fake.numpy()))

    all_losses.append(epoch_losses)
    all_d_vals.append(epoch_d_vals)
    print(
        'epoch {:03d} | time {:.2f} min | Average loss >>'
        ' Generator/Discriminator {:.4f}/{:.4f} [Discriminator-Real]: {:.4f} Discriminator-Fake: {:.4f}]'
        .format(
            epoch, (time.time() - start_time)/60,
            *list(np.mean(all_losses[-1], axis=0))))
    epoch_samples.append(
        create_samples(gen_model, fixed_z).numpy())
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7aa2c5f0b7f0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7aa2c5f0b7f0>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7aa2c5f0b7f0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7aa2c5f0b7f0>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function train_step at 0x7aa1ee192710> and will run it as-is.
# Cause: Unable to locate the source code of <function train_step at 0x7aa1ee192710>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function train_step at 0x7aa1ee192710> and will run it as-is.
# Cause: Unable to locate the source code of <function train_step at 0x7aa1ee192710>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# epoch 001 | time 0.14 min | Average loss >> Generator/Discriminator 2.8885/0.3137 [Discriminator-Real]: 0.0412 Discriminator-Fake: 0.2726]
# epoch 002 | time 0.22 min | Average loss >> Generator/Discriminator 4.7916/0.3314 [Discriminator-Real]: 0.1108 Discriminator-Fake: 0.2206]
# epoch 003 | time 0.30 min | Average loss >> Generator/Discriminator 3.3467/0.6929 [Discriminator-Real]: 0.3125 Discriminator-Fake: 0.3804]
# epoch 004 | time 0.38 min | Average loss >> Generator/Discriminator 2.3834/0.7968 [Discriminator-Real]: 0.4050 Discriminator-Fake: 0.3918]
# epoch 005 | time 0.45 min | Average loss >> Generator/Discriminator 2.1258/0.7866 [Discriminator-Real]: 0.4345 Discriminator-Fake: 0.3521]
# epoch 006 | time 0.53 min | Average loss >> Generator/Discriminator 1.8199/0.8649 [Discriminator-Real]: 0.4790 Discriminator-Fake: 0.3859]
# epoch 007 | time 0.60 min | Average loss >> Generator/Discriminator 1.6478/0.9629 [Discriminator-Real]: 0.5221 Discriminator-Fake: 0.4408]
# epoch 008 | time 0.68 min | Average loss >> Generator/Discriminator 1.5841/0.9638 [Discriminator-Real]: 0.5300 Discriminator-Fake: 0.4338]
# epoch 009 | time 0.75 min | Average loss >> Generator/Discriminator 1.4104/1.0411 [Discriminator-Real]: 0.5612 Discriminator-Fake: 0.4799]
# epoch 010 | time 0.83 min | Average loss >> Generator/Discriminator 1.3061/1.0699 [Discriminator-Real]: 0.5747 Discriminator-Fake: 0.4953]
# epoch 011 | time 0.90 min | Average loss >> Generator/Discriminator 1.3938/1.0878 [Discriminator-Real]: 0.5728 Discriminator-Fake: 0.5150]
# epoch 012 | time 0.98 min | Average loss >> Generator/Discriminator 1.3069/1.1051 [Discriminator-Real]: 0.5822 Discriminator-Fake: 0.5229]
# epoch 013 | time 1.05 min | Average loss >> Generator/Discriminator 1.2494/1.1126 [Discriminator-Real]: 0.5844 Discriminator-Fake: 0.5282]
# epoch 014 | time 1.13 min | Average loss >> Generator/Discriminator 1.2912/1.1197 [Discriminator-Real]: 0.5852 Discriminator-Fake: 0.5345]
# epoch 015 | time 1.20 min | Average loss >> Generator/Discriminator 1.2480/1.1344 [Discriminator-Real]: 0.5901 Discriminator-Fake: 0.5443]
# epoch 016 | time 1.27 min | Average loss >> Generator/Discriminator 1.1816/1.1758 [Discriminator-Real]: 0.6082 Discriminator-Fake: 0.5676]
# epoch 017 | time 1.35 min | Average loss >> Generator/Discriminator 1.1710/1.1621 [Discriminator-Real]: 0.6007 Discriminator-Fake: 0.5614]
# epoch 018 | time 1.42 min | Average loss >> Generator/Discriminator 1.2098/1.1638 [Discriminator-Real]: 0.5962 Discriminator-Fake: 0.5677]
# epoch 019 | time 1.49 min | Average loss >> Generator/Discriminator 1.1871/1.1581 [Discriminator-Real]: 0.5942 Discriminator-Fake: 0.5639]
# epoch 020 | time 1.57 min | Average loss >> Generator/Discriminator 1.0901/1.2197 [Discriminator-Real]: 0.6231 Discriminator-Fake: 0.5966]
# epoch 021 | time 1.64 min | Average loss >> Generator/Discriminator 1.1062/1.2011 [Discriminator-Real]: 0.6145 Discriminator-Fake: 0.5866]
# epoch 022 | time 1.71 min | Average loss >> Generator/Discriminator 1.1402/1.1889 [Discriminator-Real]: 0.6098 Discriminator-Fake: 0.5791]
# epoch 023 | time 1.79 min | Average loss >> Generator/Discriminator 1.0853/1.2216 [Discriminator-Real]: 0.6186 Discriminator-Fake: 0.6030]
# epoch 024 | time 1.86 min | Average loss >> Generator/Discriminator 1.0601/1.2192 [Discriminator-Real]: 0.6239 Discriminator-Fake: 0.5952]
# epoch 025 | time 1.93 min | Average loss >> Generator/Discriminator 1.0684/1.2234 [Discriminator-Real]: 0.6216 Discriminator-Fake: 0.6018]
# epoch 026 | time 2.00 min | Average loss >> Generator/Discriminator 1.0586/1.2596 [Discriminator-Real]: 0.6329 Discriminator-Fake: 0.6267]
# epoch 027 | time 2.08 min | Average loss >> Generator/Discriminator 1.0587/1.2404 [Discriminator-Real]: 0.6277 Discriminator-Fake: 0.6127]
# epoch 028 | time 2.15 min | Average loss >> Generator/Discriminator 1.0537/1.2377 [Discriminator-Real]: 0.6264 Discriminator-Fake: 0.6113]
# epoch 029 | time 2.22 min | Average loss >> Generator/Discriminator 1.0326/1.2424 [Discriminator-Real]: 0.6292 Discriminator-Fake: 0.6132]
# epoch 030 | time 2.30 min | Average loss >> Generator/Discriminator 1.0542/1.2437 [Discriminator-Real]: 0.6284 Discriminator-Fake: 0.6153]
# epoch 031 | time 2.37 min | Average loss >> Generator/Discriminator 1.0258/1.2471 [Discriminator-Real]: 0.6324 Discriminator-Fake: 0.6147]
# epoch 032 | time 2.44 min | Average loss >> Generator/Discriminator 0.9904/1.2436 [Discriminator-Real]: 0.6315 Discriminator-Fake: 0.6121]
# epoch 033 | time 2.52 min | Average loss >> Generator/Discriminator 1.0201/1.2612 [Discriminator-Real]: 0.6346 Discriminator-Fake: 0.6266]
# epoch 034 | time 2.59 min | Average loss >> Generator/Discriminator 0.9973/1.2615 [Discriminator-Real]: 0.6391 Discriminator-Fake: 0.6224]
# epoch 035 | time 2.66 min | Average loss >> Generator/Discriminator 0.9560/1.2971 [Discriminator-Real]: 0.6523 Discriminator-Fake: 0.6447]
# epoch 036 | time 2.74 min | Average loss >> Generator/Discriminator 0.9895/1.2847 [Discriminator-Real]: 0.6450 Discriminator-Fake: 0.6398]
# epoch 037 | time 2.81 min | Average loss >> Generator/Discriminator 1.0441/1.2556 [Discriminator-Real]: 0.6315 Discriminator-Fake: 0.6241]
# epoch 038 | time 2.88 min | Average loss >> Generator/Discriminator 1.0168/1.2527 [Discriminator-Real]: 0.6323 Discriminator-Fake: 0.6204]
# epoch 039 | time 2.96 min | Average loss >> Generator/Discriminator 0.9297/1.2776 [Discriminator-Real]: 0.6467 Discriminator-Fake: 0.6309]
# epoch 040 | time 3.03 min | Average loss >> Generator/Discriminator 0.9649/1.2754 [Discriminator-Real]: 0.6429 Discriminator-Fake: 0.6325]
# epoch 041 | time 3.10 min | Average loss >> Generator/Discriminator 1.0280/1.2649 [Discriminator-Real]: 0.6369 Discriminator-Fake: 0.6280]
# epoch 042 | time 3.17 min | Average loss >> Generator/Discriminator 0.9463/1.2985 [Discriminator-Real]: 0.6529 Discriminator-Fake: 0.6457]
# epoch 043 | time 3.24 min | Average loss >> Generator/Discriminator 0.9887/1.2809 [Discriminator-Real]: 0.6414 Discriminator-Fake: 0.6394]
# epoch 044 | time 3.32 min | Average loss >> Generator/Discriminator 0.9294/1.2962 [Discriminator-Real]: 0.6523 Discriminator-Fake: 0.6438]
# epoch 045 | time 3.39 min | Average loss >> Generator/Discriminator 0.9511/1.2977 [Discriminator-Real]: 0.6513 Discriminator-Fake: 0.6464]
# epoch 046 | time 3.46 min | Average loss >> Generator/Discriminator 0.9696/1.2987 [Discriminator-Real]: 0.6519 Discriminator-Fake: 0.6468]
# epoch 047 | time 3.53 min | Average loss >> Generator/Discriminator 0.9595/1.2967 [Discriminator-Real]: 0.6523 Discriminator-Fake: 0.6445]
# epoch 048 | time 3.61 min | Average loss >> Generator/Discriminator 0.9681/1.2856 [Discriminator-Real]: 0.6454 Discriminator-Fake: 0.6402]
# epoch 049 | time 3.68 min | Average loss >> Generator/Discriminator 0.9759/1.2854 [Discriminator-Real]: 0.6466 Discriminator-Fake: 0.6388]
# epoch 050 | time 3.75 min | Average loss >> Generator/Discriminator 0.9360/1.2989 [Discriminator-Real]: 0.6510 Discriminator-Fake: 0.6478]
# epoch 051 | time 3.83 min | Average loss >> Generator/Discriminator 0.9008/1.3119 [Discriminator-Real]: 0.6586 Discriminator-Fake: 0.6532]
# epoch 052 | time 3.90 min | Average loss >> Generator/Discriminator 0.9607/1.3004 [Discriminator-Real]: 0.6521 Discriminator-Fake: 0.6483]
# epoch 053 | time 3.97 min | Average loss >> Generator/Discriminator 0.9813/1.2872 [Discriminator-Real]: 0.6466 Discriminator-Fake: 0.6406]
# epoch 054 | time 4.05 min | Average loss >> Generator/Discriminator 0.9556/1.2912 [Discriminator-Real]: 0.6505 Discriminator-Fake: 0.6407]
# epoch 055 | time 4.12 min | Average loss >> Generator/Discriminator 0.9220/1.2890 [Discriminator-Real]: 0.6492 Discriminator-Fake: 0.6398]
# epoch 056 | time 4.19 min | Average loss >> Generator/Discriminator 0.9482/1.2921 [Discriminator-Real]: 0.6487 Discriminator-Fake: 0.6435]
# epoch 057 | time 4.26 min | Average loss >> Generator/Discriminator 0.9686/1.2952 [Discriminator-Real]: 0.6496 Discriminator-Fake: 0.6456]
# epoch 058 | time 4.34 min | Average loss >> Generator/Discriminator 0.9342/1.2999 [Discriminator-Real]: 0.6532 Discriminator-Fake: 0.6467]
# epoch 059 | time 4.41 min | Average loss >> Generator/Discriminator 0.9106/1.3018 [Discriminator-Real]: 0.6561 Discriminator-Fake: 0.6457]
# epoch 060 | time 4.48 min | Average loss >> Generator/Discriminator 0.9939/1.2855 [Discriminator-Real]: 0.6459 Discriminator-Fake: 0.6396]
# epoch 061 | time 4.56 min | Average loss >> Generator/Discriminator 0.9607/1.2860 [Discriminator-Real]: 0.6461 Discriminator-Fake: 0.6399]
# epoch 062 | time 4.63 min | Average loss >> Generator/Discriminator 0.9050/1.3036 [Discriminator-Real]: 0.6552 Discriminator-Fake: 0.6484]
# epoch 063 | time 4.70 min | Average loss >> Generator/Discriminator 0.9231/1.3093 [Discriminator-Real]: 0.6557 Discriminator-Fake: 0.6536]
# epoch 064 | time 4.78 min | Average loss >> Generator/Discriminator 0.9550/1.3009 [Discriminator-Real]: 0.6518 Discriminator-Fake: 0.6491]
# epoch 065 | time 4.85 min | Average loss >> Generator/Discriminator 0.9340/1.2989 [Discriminator-Real]: 0.6534 Discriminator-Fake: 0.6455]
# epoch 066 | time 4.92 min | Average loss >> Generator/Discriminator 0.9592/1.2965 [Discriminator-Real]: 0.6503 Discriminator-Fake: 0.6462]
# epoch 067 | time 5.00 min | Average loss >> Generator/Discriminator 0.9131/1.3052 [Discriminator-Real]: 0.6579 Discriminator-Fake: 0.6472]
# epoch 068 | time 5.07 min | Average loss >> Generator/Discriminator 0.9228/1.3070 [Discriminator-Real]: 0.6546 Discriminator-Fake: 0.6524]
# epoch 069 | time 5.14 min | Average loss >> Generator/Discriminator 0.8982/1.3261 [Discriminator-Real]: 0.6647 Discriminator-Fake: 0.6615]
# epoch 070 | time 5.22 min | Average loss >> Generator/Discriminator 0.9517/1.3024 [Discriminator-Real]: 0.6525 Discriminator-Fake: 0.6499]
# epoch 071 | time 5.29 min | Average loss >> Generator/Discriminator 0.9282/1.3091 [Discriminator-Real]: 0.6581 Discriminator-Fake: 0.6510]
[Discriminator-Real]: 0.6586 Discriminator-Fake: 0.6533]
# epoch 093 | time 6.91 min | Average loss >> Generator/Discriminator 0.8783/1.3279 [Discriminator-Real]: 0.6671 Discriminator-Fake: 0.6608]
# epoch 094 | time 6.98 min | Average loss >> Generator/Discriminator 0.9167/1.3235 [Discriminator-Real]: 0.6656 Discriminator-Fake: 0.6579]
# epoch 095 | time 7.06 min | Average loss >> Generator/Discriminator 0.9465/1.3120 [Discriminator-Real]: 0.6585 Discriminator-Fake: 0.6535]
# epoch 096 | time 7.13 min | Average loss >> Generator/Discriminator 0.8851/1.3229 [Discriminator-Real]: 0.6634 Discriminator-Fake: 0.6594]
# epoch 097 | time 7.20 min | Average loss >> Generator/Discriminator 0.9601/1.3068 [Discriminator-Real]: 0.6525 Discriminator-Fake: 0.6543]
# epoch 098 | time 7.27 min | Average loss >> Generator/Discriminator 0.9333/1.3065 [Discriminator-Real]: 0.6545 Discriminator-Fake: 0.6520]
# epoch 099 | time 7.35 min | Average loss >> Generator/Discriminator 0.8726/1.3269 [Discriminator-Real]: 0.6660 Discriminator-Fake: 0.6610]
# epoch 100 | time 7.42 min | Average loss >> Generator/Discriminator 0.9093/1.3302 [Discriminator-Real]: 0.6658 Discriminator-Fake: 0.6644]
# epoch 101 | time 7.49 min | Average loss >> Generator/Discriminator 0.9428/1.3089 [Discriminator-Real]: 0.6556 Discriminator-Fake: 0.6533]
# epoch 102 | time 7.57 min | Average loss >> Generator/Discriminator 0.9013/1.3142 [Discriminator-Real]: 0.6602 Discriminator-Fake: 0.6540]
# epoch 103 | time 7.64 min | Average loss >> Generator/Discriminator 0.9158/1.3192 [Discriminator-Real]: 0.6620 Discriminator-Fake: 0.6572]
# epoch 104 | time 7.71 min | Average loss >> Generator/Discriminator 0.9539/1.3052 [Discriminator-Real]: 0.6543 Discriminator-Fake: 0.6509]
# epoch 105 | time 7.79 min | Average loss >> Generator/Discriminator 0.8840/1.3135 [Discriminator-Real]: 0.6604 Discriminator-Fake: 0.6531]
# epoch 106 | time 7.86 min | Average loss >> Generator/Discriminator 0.8983/1.3209 [Discriminator-Real]: 0.6617 Discriminator-Fake: 0.6593]
# epoch 107 | time 7.93 min | Average loss >> Generator/Discriminator 0.9382/1.3117 [Discriminator-Real]: 0.6586 Discriminator-Fake: 0.6531]
# epoch 108 | time 8.01 min | Average loss >> Generator/Discriminator 0.9424/1.3090 [Discriminator-Real]: 0.6548 Discriminator-Fake: 0.6542]
# epoch 109 | time 8.08 min | Average loss >> Generator/Discriminator 0.9090/1.3133 [Discriminator-Real]: 0.6601 Discriminator-Fake: 0.6532]
# epoch 110 | time 8.15 min | Average loss >> Generator/Discriminator 0.9010/1.3217 [Discriminator-Real]: 0.6614 Discriminator-Fake: 0.6602]
# epoch 111 | time 8.23 min | Average loss >> Generator/Discriminator 0.8998/1.3254 [Discriminator-Real]: 0.6632 Discriminator-Fake: 0.6622]
# epoch 112 | time 8.30 min | Average loss >> Generator/Discriminator 0.9304/1.3063 [Discriminator-Real]: 0.6562 Discriminator-Fake: 0.6500]
# epoch 113 | time 8.37 min | Average loss >> Generator/Discriminator 0.9140/1.3153 [Discriminator-Real]: 0.6615 Discriminator-Fake: 0.6538]
# epoch 114 | time 8.45 min | Average loss >> Generator/Discriminator 0.9070/1.3237 [Discriminator-Real]: 0.6643 Discriminator-Fake: 0.6594]
# epoch 115 | time 8.52 min | Average loss >> Generator/Discriminator 0.9221/1.3206 [Discriminator-Real]: 0.6608 Discriminator-Fake: 0.6598]
# epoch 116 | time 8.59 min | Average loss >> Generator/Discriminator 0.9010/1.3202 [Discriminator-Real]: 0.6642 Discriminator-Fake: 0.6561]
# epoch 117 | time 8.67 min | Average loss >> Generator/Discriminator 0.9193/1.3297 [Discriminator-Real]: 0.6659 Discriminator-Fake: 0.6638]
# epoch 118 | time 8.74 min | Average loss >> Generator/Discriminator 0.9120/1.3164 [Discriminator-Real]: 0.6631 Discriminator-Fake: 0.6532]
# epoch 119 | time 8.82 min | Average loss >> Generator/Discriminator 0.9240/1.3153 [Discriminator-Real]: 0.6591 Discriminator-Fake: 0.6562]
# epoch 120 | time 8.89 min | Average loss >> Generator/Discriminator 0.8933/1.3180 [Discriminator-Real]: 0.6605 Discriminator-Fake: 0.6574]
# epoch 121 | time 8.96 min | Average loss >> Generator/Discriminator 0.9407/1.3165 [Discriminator-Real]: 0.6596 Discriminator-Fake: 0.6569]
# epoch 122 | time 9.04 min | Average loss >> Generator/Discriminator 0.8918/1.3162 [Discriminator-Real]: 0.6609 Discriminator-Fake: 0.6553]
# epoch 123 | time 9.11 min | Average loss >> Generator/Discriminator 0.9032/1.3275 [Discriminator-Real]: 0.6639 Discriminator-Fake: 0.6635]
# epoch 124 | time 9.18 min | Average loss >> Generator/Discriminator 0.9547/1.3105 [Discriminator-Real]: 0.6564 Discriminator-Fake: 0.6542]
# epoch 125 | time 9.26 min | Average loss >> Generator/Discriminator 0.8860/1.3130 [Discriminator-Real]: 0.6601 Discriminator-Fake: 0.6530]
# epoch 126 | time 9.33 min | Average loss >> Generator/Discriminator 0.9185/1.3196 [Discriminator-Real]: 0.6605 Discriminator-Fake: 0.6590]
# epoch 127 | time 9.40 min | Average loss >> Generator/Discriminator 0.9177/1.3153 [Discriminator-Real]: 0.6575 Discriminator-Fake: 0.6578]
# epoch 128 | time 9.48 min | Average loss >> Generator/Discriminator 0.8962/1.3215 [Discriminator-Real]: 0.6635 Discriminator-Fake: 0.6579]
# epoch 129 | time 9.55 min | Average loss >> Generator/Discriminator 0.9068/1.3207 [Discriminator-Real]: 0.6613 Discriminator-Fake: 0.6594]
# epoch 130 | time 9.62 min | Average loss >> Generator/Discriminator 0.9504/1.3104 [Discriminator-Real]: 0.6592 Discriminator-Fake: 0.6513]
# epoch 131 | time 9.70 min | Average loss >> Generator/Discriminator 0.9280/1.3252 [Discriminator-Real]: 0.6633 Discriminator-Fake: 0.6619]
# epoch 132 | time 9.77 min | Average loss >> Generator/Discriminator 0.9153/1.3172 [Discriminator-Real]: 0.6634 Discriminator-Fake: 0.6537]
# epoch 133 | time 9.84 min | Average loss >> Generator/Discriminator 0.9043/1.3250 [Discriminator-Real]: 0.6648 Discriminator-Fake: 0.6603]
# epoch 134 | time 9.92 min | Average loss >> Generator/Discriminator 0.8957/1.3241 [Discriminator-Real]: 0.6672 Discriminator-Fake: 0.6569]
# epoch 135 | time 9.99 min | Average loss >> Generator/Discriminator 0.9444/1.3055 [Discriminator-Real]: 0.6570 Discriminator-Fake: 0.6485]
# epoch 136 | time 10.06 min | Average loss >> Generator/Discriminator 0.9209/1.3087 [Discriminator-Real]: 0.6573 Discriminator-Fake: 0.6514]
# epoch 137 | time 10.14 min | Average loss >> Generator/Discriminator 0.9028/1.3177 [Discriminator-Real]: 0.6612 Discriminator-Fake: 0.6565]
# epoch 138 | time 10.21 min | Average loss >> Generator/Discriminator 0.9333/1.3149 [Discriminator-Real]: 0.6589 Discriminator-Fake: 0.6561]
# epoch 139 | time 10.28 min | Average loss >> Generator/Discriminator 0.9008/1.3267 [Discriminator-Real]: 0.6646 Discriminator-Fake: 0.6621]
# epoch 140 | time 10.35 min | Average loss >> Generator/Discriminator 0.9951/1.3077 [Discriminator-Real]: 0.6519 Discriminator-Fake: 0.6559]
# epoch 141 | time 10.42 min | Average loss >> Generator/Discriminator 0.8714/1.3229 [Discriminator-Real]: 0.6655 Discriminator-Fake: 0.6575]
# epoch 142 | time 10.50 min | Average loss >> Generator/Discriminator 0.9517/1.3189 [Discriminator-Real]: 0.6608 Discriminator-Fake: 0.6581]
# epoch 143 | time 10.57 min | Average loss >> Generator/Discriminator 0.9059/1.3225 [Discriminator-Real]: 0.6641 Discriminator-Fake: 0.6584]
# epoch 144 | time 10.65 min | Average loss >> Generator/Discriminator 0.8947/1.3273 [Discriminator-Real]: 0.6650 Discriminator-Fake: 0.6622]
# epoch 145 | time 10.72 min | Average loss >> Generator/Discriminator 0.9212/1.3181 [Discriminator-Real]: 0.6601 Discriminator-Fake: 0.6579]
# epoch 146 | time 10.79 min | Average loss >> Generator/Discriminator 0.9072/1.3189 [Discriminator-Real]: 0.6614 Discriminator-Fake: 0.6574]
# epoch 147 | time 10.86 min | Average loss >> Generator/Discriminator 0.9351/1.3270 [Discriminator-Real]: 0.6661 Discriminator-Fake: 0.6609]
# epoch 148 | time 10.94 min | Average loss >> Generator/Discriminator 0.8996/1.3222 [Discriminator-Real]: 0.6635 Discriminator-Fake: 0.6587]
# epoch 149 | time 11.01 min | Average loss >> Generator/Discriminator 0.9139/1.3220 [Discriminator-Real]: 0.6621 Discriminator-Fake: 0.6599]
# epoch 150 | time 11.08 min | Average loss >> Generator/Discriminator 0.9012/1.3189 [Discriminator-Real]: 0.6637 Discriminator-Fake: 0.6552]
# epoch 151 | time 11.16 min | Average loss >> Generator/Discriminator 0.9504/1.3217 [Discriminator-Real]: 0.6611 Discriminator-Fake: 0.6606]
# epoch 152 | time 11.23 min | Average loss >> Generator/Discriminator 0.9250/1.3038 [Discriminator-Real]: 0.6560 Discriminator-Fake: 0.6479]
# epoch 153 | time 11.30 min | Average loss >> Generator/Discriminator 0.8967/1.3190 [Discriminator-Real]: 0.6632 Discriminator-Fake: 0.6558]
# epoch 154 | time 11.38 min | Average loss >> Generator/Discriminator 0.9444/1.3128 [Discriminator-Real]: 0.6544 Discriminator-Fake: 0.6585]
# epoch 260 | time 19.11 min | Average loss >> Generator/Discriminator 0.9284/1.3195 [Discriminator-Real]: 0.6599 Discriminator-Fake: 0.6596]
# epoch 261 | time 19.18 min | Average loss >> Generator/Discriminator 0.9516/1.3257 [Discriminator-Real]: 0.6650 Discriminator-Fake: 0.6607]
# epoch 262 | time 19.25 min | Average loss >> Generator/Discriminator 0.9268/1.3040 [Discriminator-Real]: 0.6545 Discriminator-Fake: 0.6495]
# epoch 263 | time 19.32 min | Average loss >> Generator/Discriminator 0.9604/1.3186 [Discriminator-Real]: 0.6606 Discriminator-Fake: 0.6580]
# epoch 264 | time 19.40 min | Average loss >> Generator/Discriminator 0.9157/1.3119 [Discriminator-Real]: 0.6584 Discriminator-Fake: 0.6535]
# epoch 265 | time 19.47 min | Average loss >> Generator/Discriminator 0.9254/1.3240 [Discriminator-Real]: 0.6623 Discriminator-Fake: 0.6616]
# epoch 266 | time 19.54 min | Average loss >> Generator/Discriminator 0.9534/1.3094 [Discriminator-Real]: 0.6572 Discriminator-Fake: 0.6522]
# epoch 267 | time 19.61 min | Average loss >> Generator/Discriminator 0.9817/1.3074 [Discriminator-Real]: 0.6563 Discriminator-Fake: 0.6511]
# epoch 268 | time 19.69 min | Average loss >> Generator/Discriminator 0.9092/1.3112 [Discriminator-Real]: 0.6579 Discriminator-Fake: 0.6533]
# epoch 269 | time 19.76 min | Average loss >> Generator/Discriminator 0.9538/1.3172 [Discriminator-Real]: 0.6594 Discriminator-Fake: 0.6578]
# epoch 270 | time 19.83 min | Average loss >> Generator/Discriminator 0.9068/1.3157 [Discriminator-Real]: 0.6614 Discriminator-Fake: 0.6543]
# epoch 271 | time 19.90 min | Average loss >> Generator/Discriminator 0.9403/1.3162 [Discriminator-Real]: 0.6601 Discriminator-Fake: 0.6560]
# epoch 272 | time 19.98 min | Average loss >> Generator/Discriminator 0.9157/1.3100 [Discriminator-Real]: 0.6575 Discriminator-Fake: 0.6525]
# epoch 273 | time 20.05 min | Average loss >> Generator/Discriminator 0.9402/1.3139 [Discriminator-Real]: 0.6589 Discriminator-Fake: 0.6550]
# epoch 274 | time 20.12 min | Average loss >> Generator/Discriminator 0.9523/1.3159 [Discriminator-Real]: 0.6595 Discriminator-Fake: 0.6564]
# epoch 275 | time 20.20 min | Average loss >> Generator/Discriminator 0.9221/1.3057 [Discriminator-Real]: 0.6558 Discriminator-Fake: 0.6499]
# epoch 276 | time 20.27 min | Average loss >> Generator/Discriminator 0.9778/1.3256 [Discriminator-Real]: 0.6622 Discriminator-Fake: 0.6634]
# epoch 277 | time 20.34 min | Average loss >> Generator/Discriminator 0.9323/1.3028 [Discriminator-Real]: 0.6556 Discriminator-Fake: 0.6472]
# epoch 278 | time 20.41 min | Average loss >> Generator/Discriminator 0.9410/1.3224 [Discriminator-Real]: 0.6639 Discriminator-Fake: 0.6585]
# epoch 279 | time 20.49 min | Average loss >> Generator/Discriminator 0.9401/1.3140 [Discriminator-Real]: 0.6594 Discriminator-Fake: 0.6546]
# epoch 440 | time 32.22 min | Average loss >> Generator/Discriminator 0.9278/1.3013 [Discriminator-Real]: 0.6522 Discriminator-Fake: 0.6492]
# epoch 441 | time 32.29 min | Average loss >> Generator/Discriminator 0.9396/1.3025 [Discriminator-Real]: 0.6535 Discriminator-Fake: 0.6490]
# epoch 442 | time 32.37 min | Average loss >> Generator/Discriminator 0.9182/1.3094 [Discriminator-Real]: 0.6568 Discriminator-Fake: 0.6526]
# epoch 443 | time 32.44 min | Average loss >> Generator/Discriminator 0.9318/1.3098 [Discriminator-Real]: 0.6556 Discriminator-Fake: 0.6542]
# epoch 444 | time 32.51 min | Average loss >> Generator/Discriminator 0.9551/1.3037 [Discriminator-Real]: 0.6521 Discriminator-Fake: 0.6517]
# epoch 445 | time 32.59 min | Average loss >> Generator/Discriminator 0.9415/1.2963 [Discriminator-Real]: 0.6505 Discriminator-Fake: 0.6458]
# epoch 446 | time 32.66 min | Average loss >> Generator/Discriminator 0.9353/1.3027 [Discriminator-Real]: 0.6530 Discriminator-Fake: 0.6497]
# epoch 447 | time 32.73 min | Average loss >> Generator/Discriminator 0.9257/1.3003 [Discriminator-Real]: 0.6520 Discriminator-Fake: 0.6483]
# epoch 448 | time 32.80 min | Average loss >> Generator/Discriminator 0.9476/1.3014 [Discriminator-Real]: 0.6518 Discriminator-Fake: 0.6496]
# epoch 449 | time 32.88 min | Average loss >> Generator/Discriminator 0.9421/1.3071 [Discriminator-Real]: 0.6543 Discriminator-Fake: 0.6529]
# epoch 450 | time 32.95 min | Average loss >> Generator/Discriminator 0.9367/1.3013 [Discriminator-Real]: 0.6533 Discriminator-Fake: 0.6480]
# epoch 451 | time 33.02 min | Average loss >> Generator/Discriminator 0.9347/1.3011 [Discriminator-Real]: 0.6531 Discriminator-Fake: 0.6481]
# epoch 452 | time 33.09 min | Average loss >> Generator/Discriminator 0.9441/1.2976 [Discriminator-Real]: 0.6526 Discriminator-Fake: 0.6451]
# epoch 453 | time 33.17 min | Average loss >> Generator/Discriminator 0.9456/1.2972 [Discriminator-Real]: 0.6499 Discriminator-Fake: 0.6473]
# epoch 454 | time 33.24 min | Average loss >> Generator/Discriminator 0.9505/1.2920 [Discriminator-Real]: 0.6489 Discriminator-Fake: 0.6430]
# epoch 455 | time 33.31 min | Average loss >> Generator/Discriminator 0.9486/1.2959 [Discriminator-Real]: 0.6509 Discriminator-Fake: 0.6450]
# epoch 456 | time 33.39 min | Average loss >> Generator/Discriminator 0.9494/1.2918 [Discriminator-Real]: 0.6481 Discriminator-Fake: 0.6437]
# epoch 457 | time 33.46 min | Average loss >> Generator/Discriminator 0.9408/1.2962 [Discriminator-Real]: 0.6497 Discriminator-Fake: 0.6465]
# epoch 458 | time 33.53 min | Average loss >> Generator/Discriminator 0.9438/1.2926 [Discriminator-Real]: 0.6495 Discriminator-Fake: 0.6431]
# epoch 459 | time 33.60 min | Average loss >> Generator/Discriminator 0.9432/1.3033 [Discriminator-Real]: 0.6531 Discriminator-Fake: 0.6502]
# epoch 460 | time 33.68 min | Average loss >> Generator/Discriminator 0.9321/1.3014 [Discriminator-Real]: 0.6534 Discriminator-Fake: 0.6480]
# epoch 481 | time 35.21 min | Average loss >> Generator/Discriminator 0.9181/1.2990 [Discriminator-Real]: 0.6528 Discriminator-Fake: 0.6462]
# epoch 482 | time 35.28 min | Average loss >> Generator/Discriminator 0.9344/1.3036 [Discriminator-Real]: 0.6540 Discriminator-Fake: 0.6496]
# epoch 483 | time 35.36 min | Average loss >> Generator/Discriminator 0.9623/1.2894 [Discriminator-Real]: 0.6468 Discriminator-Fake: 0.6425]
# epoch 484 | time 35.43 min | Average loss >> Generator/Discriminator 0.9158/1.3047 [Discriminator-Real]: 0.6539 Discriminator-Fake: 0.6508]
# epoch 485 | time 35.50 min | Average loss >> Generator/Discriminator 0.9293/1.3047 [Discriminator-Real]: 0.6552 Discriminator-Fake: 0.6495]
# epoch 486 | time 35.58 min | Average loss >> Generator/Discriminator 0.9408/1.3007 [Discriminator-Real]: 0.6506 Discriminator-Fake: 0.6501]
# epoch 487 | time 35.65 min | Average loss >> Generator/Discriminator 0.9448/1.2913 [Discriminator-Real]: 0.6470 Discriminator-Fake: 0.6443]
# epoch 488 | time 35.72 min | Average loss >> Generator/Discriminator 0.9314/1.2950 [Discriminator-Real]: 0.6496 Discriminator-Fake: 0.6455]
# epoch 489 | time 35.80 min | Average loss >> Generator/Discriminator 0.9220/1.3026 [Discriminator-Real]: 0.6539 Discriminator-Fake: 0.6487]
# epoch 490 | time 35.87 min | Average loss >> Generator/Discriminator 0.9518/1.3013 [Discriminator-Real]: 0.6517 Discriminator-Fake: 0.6496]
# epoch 491 | time 35.94 min | Average loss >> Generator/Discriminator 0.9349/1.2902 [Discriminator-Real]: 0.6474 Discriminator-Fake: 0.6427]
# epoch 492 | time 36.02 min | Average loss >> Generator/Discriminator 0.9327/1.3085 [Discriminator-Real]: 0.6557 Discriminator-Fake: 0.6528]
# epoch 493 | time 36.09 min | Average loss >> Generator/Discriminator 0.9389/1.2966 [Discriminator-Real]: 0.6500 Discriminator-Fake: 0.6466]
# epoch 494 | time 36.16 min | Average loss >> Generator/Discriminator 0.9552/1.2970 [Discriminator-Real]: 0.6508 Discriminator-Fake: 0.6462]
# epoch 495 | time 36.24 min | Average loss >> Generator/Discriminator 0.9533/1.2899 [Discriminator-Real]: 0.6479 Discriminator-Fake: 0.6420]
# epoch 496 | time 36.31 min | Average loss >> Generator/Discriminator 0.9542/1.2915 [Discriminator-Real]: 0.6475 Discriminator-Fake: 0.6440]
# epoch 497 | time 36.39 min | Average loss >> Generator/Discriminator 0.9522/1.2894 [Discriminator-Real]: 0.6454 Discriminator-Fake: 0.6441]
# epoch 498 | time 36.47 min | Average loss >> Generator/Discriminator 0.9358/1.2968 [Discriminator-Real]: 0.6509 Discriminator-Fake: 0.6459]
# epoch 499 | time 36.54 min | Average loss >> Generator/Discriminator 0.9477/1.2930 [Discriminator-Real]: 0.6484 Discriminator-Fake: 0.6447]
# epoch 500 | time 36.62 min | Average loss >> Generator/Discriminator 0.9414/1.2984 [Discriminator-Real]: 0.6500 Discriminator-Fake: 0.6483]
# CPU times: user 1h 9min 4s, sys: 13min 22s, total: 1h 22min 26s
# Wall time: 36min 38s

# %% [markdown]
# <font color=gray>NOTA: Si utilizas GPU en Google Colab, el proceso de entrenamiento del código mencionado se realizará en una hora (más rápido en computadoras con las últimas CPU y GPU).
# Se aconseja analizar el proceso de entrenamiento de las dos redes neuronales y ver cómo evaluar su convergencia imprimiendo un gráfico de pérdidas del discriminador y del generador.</font>

# %% [markdown]
# ## Entrenamiento del modelo GAN
#
# * Además, resulta útil imprimir la probabilidad promedio de las muestras reales y falsas calculadas por el discriminador para cada iteración.
# * Si esta probabilidad es cercana a 0,5, el discriminador no puede distinguir entre imágenes reales y falsas.

# %%
import itertools

fig = plt.figure(figsize=(20, 6))

## Gráfica de pérdidas
ax = fig.add_subplot(1, 2, 1)
g_losses = [item[0] for item in itertools.chain(*all_losses)]
d_losses = [item[1]/2.0 for item in itertools.chain(*all_losses)]
plt.plot(g_losses, label='Generator loss', alpha=0.95)
plt.plot(d_losses, label='Discriminator loss', alpha=0.95)
plt.legend(fontsize=20)
ax.set_xlabel('Iteration', size=15)
ax.set_ylabel('Loss', size=15)

epochs = np.arange(1, 101)
epoch2iter = lambda e: e*len(all_losses[-1])
epoch_ticks = [1, 20, 40, 60, 80, 100]
newpos = [epoch2iter(e) for e in epoch_ticks]
ax2 = ax.twiny()
ax2.set_xticks(newpos)
ax2.set_xticklabels(epoch_ticks)
ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 60))
ax2.set_xlabel ('Epoch', size=15)
ax2.set_xlim(ax.get_xlim())
ax.tick_params(axis='both' , which='major' , labelsize=15)
ax2.tick_params(axis='both', which='major' , labelsize=15)

## Imprimir el discriminador
ax = fig.add_subplot(1, 2, 2)
d_vals_real = [item[0] for item in itertools.chain(*all_d_vals)]
d_vals_fake = [item[1] for item in itertools.chain(*all_d_vals)]
plt.plot(d_vals_real, alpha=0.75, label = r'Real: $D(#mathbf{x))$')
plt.plot(d_vals_fake, alpha=0.75, label = r'Fake: $D(G(#mathbf{z}))$')
plt.legend(fontsize=20)
ax.set_xlabel('Iteration', size=15)
ax. set_ylabel('Discriminator output', size=15)

ax2 = ax.twiny()
ax2.set_xticks(newpos)
ax2.set_xticklabels(epoch_ticks)
ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 60))
ax2. set_xlabel ('Epoch', size=15)
ax2.set_xlim(ax.get_xlim())
ax.tick_params(axis='both' , which='major' , labelsize=15)
ax2.tick_params(axis='both', which='major' , labelsize=15)

plt.show()

# %% [markdown]
# ## Entrenamiento del modelo GAN

# %%
selected_epochs = [50, 100, 200, 300, 400, 500]

fig = plt.figure(figsize=(10, 14))
for i,e in enumerate(selected_epochs):
  for j in range(5):
    ax = fig.add_subplot(6, 5, i*5+j+1)
    ax.set_xticks([])
    ax.set_yticks([])
    if j == 0:
      ax.text(
          -0.06, 0.5, 'Epoch {}'.format(e),
          rotation=90, size=18, color='red',
          horizontalalignment='right',
          verticalalignment='center',
          transform=ax.transAxes)

    image = epoch_samples[e-1][j]
    ax.imshow(image, cmap='gray_r')

plt.show()

# %%
len(epoch_samples)
# Out:
# 500
